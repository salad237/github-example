# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# For this assignment, you will be required to explore and cluster the neighborhoods in Toronto.
#
#
# Start by creating a new Notebook for this assignment.
# Use the Notebook to build the code to scrape the following Wikipedia page, https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M,

# %% [markdown]
# ## Part 1 - Scraping data from Wikipedia to create the Toronto postal code dataframe

# %% [markdown]
# To create the above dataframe:
#
# The dataframe will consist of three columns: PostalCode, Borough, and Neighborhood
# Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.
# More than one neighborhood can exist in one postal code area. For example, in the table on the Wikipedia page, you will notice that M5A is listed twice and has two neighborhoods: Harbourfront and Regent Park. These two rows will be combined into one row with the neighborhoods separated with a comma as shown in row 11 in the above table.
# If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough. So for the 9th cell in the table on the Wikipedia page, the value of the Borough and the Neighborhood columns will be Queen's Park.
# Clean your Notebook and add Markdown cells to explain your work and any assumptions you are making.
# In the last cell of your notebook, use the .shape method to print the number of rows of your dataframe.

# %% [markdown]
# Note: There are different website scraping libraries and packages in Python. For scraping the above table, you can simply use pandas to read the table into a pandas dataframe.
#
# Another way, which would help to learn for more complicated cases of web scraping is using the BeautifulSoup package. Here is the package's main documentation page: http://beautiful-soup-4.readthedocs.io/en/latest/
#
# The package is so popular that there is a plethora of tutorials and examples on how to use it. Here is a very good Youtube video on how to use the BeautifulSoup package: https://www.youtube.com/watch?v=ng2o98k983k
#
# Use pandas, or the BeautifulSoup package, or any other way you are comfortable with to transform the data in the table on the Wikipedia page into the above pandas dataframe.

# %% [markdown]
# ### Scraping data from Wikipedia with `BeautifulSoup` package

# %%
# importing necessary libraries
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# getting data from internet
wikipedia_link='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
raw_wikipedia_page= requests.get(wikipedia_link).text

# using beautiful soup to parse the HTML/XML codes.
soup = BeautifulSoup(raw_wikipedia_page,'xml')
#print(soup.prettify())

# extracting the raw table inside that webpage
table = soup.find('table')

Postcode      = []
Borough       = []
Neighbourhood = []

# print(table)

# extracting a clean form of the table
for tr_cell in table.find_all('tr'):
    
    counter = 1
    Postcode_var      = -1
    Borough_var       = -1
    Neighbourhood_var = -1
    
    for td_cell in tr_cell.find_all('td'):
        if counter == 1: 
            Postcode_var = td_cell.text
        if counter == 2: 
            Borough_var = td_cell.text
            tag_a_Borough = td_cell.find('a')
            
        if counter == 3: 
            Neighbourhood_var = str(td_cell.text).strip()
            tag_a_Neighbourhood = td_cell.find('a')
            
        counter +=1
        
        if (Postcode_var == 'Not assigned' or Borough_var == 'Not assigned' or Neighbourhood_var == 'Not assigned'):
            
            continue
            
           
    try:
        if ((tag_a_Borough is None) or (tag_a_Neighbourhood is None)):
            
            continue
            
            
    except:
        
        pass
    
    if(Postcode_var == -1 or Borough_var == -1 or Neighbourhood_var == -1):
        
        continue
        
        
        
        
        
    Postcode.append(Postcode_var)
    Borough.append(Borough_var)
    Neighbourhood.append(Neighbourhood_var)
    
unique_p = set(Postcode)
print('num of unique Postal codes:', len(unique_p))
Postcode_u      = []
Borough_u       = []
Neighbourhood_u = []


for postcode_unique_element in unique_p:
    p_var = ''; b_var = ''; n_var = ''; 
    for postcode_idx, postcode_element in enumerate(Postcode):
        if postcode_unique_element == postcode_element:
            p_var = postcode_element;
            b_var = Borough[postcode_idx]
            if n_var == '': 
                n_var = Neighbourhood[postcode_idx]
            else:
                n_var = n_var + ', ' + Neighbourhood[postcode_idx]
    Postcode_u.append(p_var)
    Borough_u.append(b_var)
    Neighbourhood_u.append(n_var)
    
toronto_dict = {'PostalCode':Postcode_u, 'Borough':Borough_u, 'Neighborhood':Neighbourhood_u}
df_toronto = pd.DataFrame.from_dict(toronto_dict)
df_toronto.to_csv('toronto_part1.csv')
# Out:
# num of unique Postal codes: 77

# %% [markdown]
# ### Print a sample of the Toronto postal code dataframe

# %%
df_toronto.head(30)
# Out:
#    PostalCode           Borough  \
# 0         M2H        North York
# 1         M5X  Downtown Toronto
# 2         M4E      East Toronto
# 3         M4X  Downtown Toronto
# 4         M8Y         Etobicoke
# 5         M6K      West Toronto
# 6         M1C       Scarborough
# 7         M1P       Scarborough
# 8         M5K  Downtown Toronto
# 9         M6M              York
# 10        M3J        North York
# 11        M1S       Scarborough
# 12        M1E       Scarborough
# 13        M6A        North York
# 14        M4C         East York
# 15        M4B         East York
# 16        M4T   Central Toronto
# 17        M5V  Downtown Toronto
# 18        M6R      West Toronto
# 19        M4K      East Toronto
# 20        M8X         Etobicoke
# 21        M8Z         Etobicoke
# 22        M9M        North York
# 23        M8W         Etobicoke
# 24        M1B       Scarborough
# 25        M3C        North York
# 26        M4A        North York
# 27        M1G       Scarborough
# 28        M4L      East Toronto
# 29        M9N              York
#
#                                          Neighborhood
# 0                                   Hillcrest Village
# 1              First Canadian Place, Underground city
# 2                                         The Beaches
# 3                         Cabbagetown, St. James Town
# 4   Humber Bay, Mimico NE, Old Mill South, The Que...
# 5                  Exhibition Place, Parkdale Village
# 6              Highland Creek, Rouge Hill, Port Union
# 7   Dorset Park, Scarborough Town Centre, Wexford ...
# 8            Design Exchange, Toronto Dominion Centre
# 9               Keelesdale, Mount Dennis, Silverthorn
# 10                    Northwood Park, York University
# 11                                          Agincourt
# 12                             Morningside, West Hill
# 13                   Lawrence Heights, Lawrence Manor
# 14                                   Woodbine Heights
# 15                    Woodbine Gardens, Parkview Hill
# 16                                         Moore Park
# 17  CN Tower, King and Spadina, Railway Lands, Sou...
# 18                             Parkdale, Roncesvalles
# 19                                          Riverdale
# 20                                       The Kingsway
# 21                      Mimico NW, The Queensway West
# 22                                   Emery, Humberlea
# 23                             Alderwood, Long Branch
# 24                                     Rouge, Malvern
# 25                                    Flemingdon Park
# 26                                   Victoria Village
# 27                                             Woburn
# 28                                       India Bazaar
# 29                                             Weston

# %% [markdown]
# ## Part 2 - Get the geographical coordinates of a given postal code

# %% [markdown]
# Download the csv file from https://cocl.us/Geospatial_data

# %%
# !wget -O Geospatial_data.csv https://cocl.us/Geospatial_data
# Out:
# Warning: Failed to set locale category LC_NUMERIC to en_SG.
# Warning: Failed to set locale category LC_TIME to en_SG.
# Warning: Failed to set locale category LC_COLLATE to en_SG.
# Warning: Failed to set locale category LC_MONETARY to en_SG.
# Warning: Failed to set locale category LC_MESSAGES to en_SG.
# --2019-11-25 21:31:55--  https://cocl.us/Geospatial_data
# Resolving cocl.us (cocl.us)... 161.202.50.39
# Connecting to cocl.us (cocl.us)|161.202.50.39|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-11-25 21:31:58--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 103.116.4.197
# Connecting to ibm.box.com (ibm.box.com)|103.116.4.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-11-25 21:31:59--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-11-25 21:31:59--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 103.116.4.211
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|103.116.4.211|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1
R_LpYOxWAbTLGYF4Gjt1u1ZqDInaapqdSgHOGSaL2AIlxBbNJnPLqkBrHAPhrfVOKspUfK30OOW4UXMDO97FA0ndS0F77dGj6V7dweDW_xT4ucl7e0Py--WvDQgtdg4PKVWlBivamUQNpJdWOyXtd3PRtiwPnM3ERFVzJ3J0ydokmzT4c9pPjVlAmPWbE53Gd0P3AbWYOMt2QgHzw6DdwXjoQI7-OP4RWRdL5xN-Sb6EyvC6Le-v1dyVTX2sWOE0j382jpsfAPDtsJdEkY_nShAVInks-S6d-M4HD1SL00nE9O1SAz2UUvVR1S_axG3zjmQ0cerAIRSMl1l_cxMT9moCvHk5oNWrx8GQr0JHcutDFcfTULJCgvT0iGpMy5t8DT89qym6JH-ouYD2i1M4-CpiEOVJT9iLtXCGpdl5OkEN1jhzX8V9aKtXBlGe3TL4K9n0ryoWCrPZzLdJOGJFMc1SyXgQOUuNYKjO3Z8fLi20wIc./download
# Resolving public.boxcloud.com (public.boxcloud.com)... 103.116.4.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|103.116.4.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘Geospatial_data.csv’
#
# Geospatial_data.csv 100%[===================>]   2.82K  --.-KB/s    in 0s
#
# 2019-11-25 21:32:00 (115 MB/s) - ‘Geospatial_data.csv’ saved [2891/2891]

# %%
# Load Data From CSV File

df_geo = pd.read_csv('Geospatial_data.csv')

# %% [markdown]
# Merge the Toronto postal codes with Geospatial data

# %%
df_toronto_geo = pd.merge(df_toronto, df_geo, left_on='PostalCode', right_on='Postal Code')
df_toronto_geo = df_toronto_geo.drop(columns=['Postal Code'])
df_toronto_geo.head(20)
# Out:
#    PostalCode           Borough  \
# 0         M2H        North York
# 1         M5X  Downtown Toronto
# 2         M4E      East Toronto
# 3         M4X  Downtown Toronto
# 4         M8Y         Etobicoke
# 5         M6K      West Toronto
# 6         M1C       Scarborough
# 7         M1P       Scarborough
# 8         M5K  Downtown Toronto
# 9         M6M              York
# 10        M3J        North York
# 11        M1S       Scarborough
# 12        M1E       Scarborough
# 13        M6A        North York
# 14        M4C         East York
# 15        M4B         East York
# 16        M4T   Central Toronto
# 17        M5V  Downtown Toronto
# 18        M6R      West Toronto
# 19        M4K      East Toronto
#
#                                          Neighborhood   Latitude  Longitude
# 0                                   Hillcrest Village  43.803762 -79.363452
# 1              First Canadian Place, Underground city  43.648429 -79.382280
# 2                                         The Beaches  43.676357 -79.293031
# 3                         Cabbagetown, St. James Town  43.667967 -79.367675
# 4   Humber Bay, Mimico NE, Old Mill South, The Que...  43.636258 -79.498509
# 5                  Exhibition Place, Parkdale Village  43.636847 -79.428191
# 6              Highland Creek, Rouge Hill, Port Union  43.784535 -79.160497
# 7   Dorset Park, Scarborough Town Centre, Wexford ...  43.757410 -79.273304
# 8            Design Exchange, Toronto Dominion Centre  43.647177 -79.381576
# 9               Keelesdale, Mount Dennis, Silverthorn  43.691116 -79.476013
# 10                    Northwood Park, York University  43.767980 -79.487262
# 11                                          Agincourt  43.794200 -79.262029
# 12                             Morningside, West Hill  43.763573 -79.188711
# 13                   Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 14                                   Woodbine Heights  43.695344 -79.318389
# 15                    Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 16                                         Moore Park  43.689574 -79.383160
# 17  CN Tower, King and Spadina, Railway Lands, Sou...  43.628947 -79.394420
# 18                             Parkdale, Roncesvalles  43.648960 -79.456325
# 19                                          Riverdale  43.679557 -79.352188

# %% [markdown]
# ## Part 3 - Explore and cluster the neighborhoods in Toronto
#
# You can decide to work with only boroughs that contain the word Toronto and then replicate the same analysis we did to the New York City data.
#
# Just make sure:
#
# - to add enough Markdown cells to explain what you decided to do and to report any observations you make.
# - to generate maps to visualize your neighborhoods and how they cluster together.

# %%
neighborhoods = df_toronto_geo[df_toronto_geo['Borough'].str.contains("Toronto")] 
neighborhoods
# Out:
#    PostalCode           Borough  \
# 1         M5X  Downtown Toronto
# 2         M4E      East Toronto
# 3         M4X  Downtown Toronto
# 5         M6K      West Toronto
# 8         M5K  Downtown Toronto
# 16        M4T   Central Toronto
# 17        M5V  Downtown Toronto
# 18        M6R      West Toronto
# 19        M4K      East Toronto
# 28        M4L      East Toronto
# 35        M4N   Central Toronto
# 36        M6P      West Toronto
# 37        M5L  Downtown Toronto
# 39        M6H      West Toronto
# 48        M5S  Downtown Toronto
# 50        M5A  Downtown Toronto
# 54        M5R   Central Toronto
# 57        M4Y  Downtown Toronto
# 58        M5E  Downtown Toronto
# 59        M5C  Downtown Toronto
# 60        M5P   Central Toronto
# 62        M6S      West Toronto
# 65        M6J      West Toronto
# 66        M4W  Downtown Toronto
# 67        M5J  Downtown Toronto
# 74        M5T  Downtown Toronto
# 76        M4V   Central Toronto
#
#                                          Neighborhood   Latitude  Longitude
# 1              First Canadian Place, Underground city  43.648429 -79.382280
# 2                                         The Beaches  43.676357 -79.293031
# 3                         Cabbagetown, St. James Town  43.667967 -79.367675
# 5                  Exhibition Place, Parkdale Village  43.636847 -79.428191
# 8            Design Exchange, Toronto Dominion Centre  43.647177 -79.381576
# 16                                         Moore Park  43.689574 -79.383160
# 17  CN Tower, King and Spadina, Railway Lands, Sou...  43.628947 -79.394420
# 18                             Parkdale, Roncesvalles  43.648960 -79.456325
# 19                                          Riverdale  43.679557 -79.352188
# 28                                       India Bazaar  43.668999 -79.315572
# 35                                      Lawrence Park  43.728020 -79.388790
# 36                                          High Park  43.661608 -79.464763
# 37                                     Commerce Court  43.648198 -79.379817
# 39                                 Dovercourt Village  43.669005 -79.442259
# 48                              University of Toronto  43.662696 -79.400049
# 50                                       Harbourfront  43.654260 -79.360636
# 54                               The Annex, Yorkville  43.672710 -79.405678
# 57                               Church and Wellesley  43.665860 -79.383160
# 58                                        Berczy Park  43.644771 -79.373306
# 59                                     St. James Town  43.651494 -79.375418
# 60                                  Forest Hill North  43.696948 -79.411307
# 62                                 Runnymede, Swansea  43.651571 -79.484450
# 65                           Little Portugal, Trinity  43.647927 -79.419750
# 66                                           Rosedale  43.679563 -79.377529
# 67                     Toronto Islands, Union Station  43.640816 -79.381752
# 74          Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 76                   Deer Park, Rathnelly, South Hill  43.686412 -79.400049

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### Use geopy library to get the latitude and longitude values of Toronto City.
#
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent ny_explorer, as shown below.

# %%
address = 'Toronto, ON'

geolocator = Nominatim(user_agent="trt_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto City are 43.653963, -79.387207.

# %% [markdown]
# ### Create a map of Toronto with neighborhoods superimposed on top

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11.5)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Focus on the Downtown Toronto neighborhoods
#
# Simplify the above map and segment and cluster only the neighborhoods in Downtown Toronto. So let's slice the original dataframe and create a new dataframe of the Downtown Toronto data.

# %%
downtown_data = neighborhoods[neighborhoods['Borough'] == 'Downtown Toronto'].reset_index(drop=True)
downtown_data.head()

address = 'Downtown Toronto, TO'

geolocator = Nominatim(user_agent="trt_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Downtown Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Downtown Toronto are 43.6541737, -79.3808116451341.

# %% [markdown]
# As we did with all of Toronto City, let's visualizat Downtown Toronto the neighborhoods in it.

# %%
# create map of Manhattan using latitude and longitude values
map_downtown = folium.Map(location=[latitude, longitude], zoom_start=12.5)

# add markers to map
for lat, lng, label in zip(downtown_data['Latitude'], downtown_data['Longitude'], downtown_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_downtown)  
    
map_downtown
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Next, we are going to start utilizing the Foursquare API to explore the neighborhoods and segment them.
#
# ### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'AUFFRJKVOJAJX3N5XOD0V2D1HM2Q5JSPWXEK0MNMR1V12AVN' # your Foursquare ID
CLIENT_SECRET = 'DM44B1ZJGLLJ3L51CIZQ0HZLITRBPIPIBR4BZU5V1L3XDPWZ' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: AUFFRJKVOJAJX3N5XOD0V2D1HM2Q5JSPWXEK0MNMR1V12AVN
# CLIENT_SECRET:DM44B1ZJGLLJ3L51CIZQ0HZLITRBPIPIBR4BZU5V1L3XDPWZ

# %% [markdown]
# Let's explore the first neighborhood in our dataframe.

# %%
downtown_data.loc[0, 'Neighborhood']

neighborhood_latitude = downtown_data.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = downtown_data.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = downtown_data.loc[0, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of First Canadian Place, Underground city are 43.6484292, -79.3822802.

# %% [markdown]
# Now, let's get the top 100 venues that are in First Canadian Place within a radius of 500 meters.
#
# First, let's create the GET request URL. Name your URL url.

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API

radius = 500 # define radius

# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)

# %%
results = requests.get(url).json()

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                     name            categories        lat        lng
# 0                  Canoe            Restaurant  43.647452 -79.381320
# 1     Equinox Bay Street                   Gym  43.648100 -79.379989
# 2       Cactus Club Cafe   American Restaurant  43.649552 -79.381671
# 3  Pilot Coffee Roasters           Coffee Shop  43.648835 -79.380936
# 4  Adelaide Club Toronto  Gym / Fitness Center  43.649279 -79.381921

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 100 venues were returned by Foursquare.

# %% [markdown]
# ### Explore Neighborhoods in Downtown Toronto
#
# Create a function to repeat the same process to all the neighborhoods in Downtown Toronto

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# Run the above function on each neighborhood and create a new dataframe called `downtown_venues`

# %%
downtown_venues = getNearbyVenues(names=downtown_data['Neighborhood'],
                                   latitudes=downtown_data['Latitude'],
                                   longitudes=downtown_data['Longitude']
                                  )
# Out:
# First Canadian Place, Underground city
# Cabbagetown, St. James Town
# Design Exchange, Toronto Dominion Centre
# CN Tower, King and Spadina, Railway Lands, South Niagara
# Commerce Court
# University of Toronto
# Harbourfront
# Church and Wellesley
# Berczy Park
# St. James Town
# Rosedale
# Toronto Islands, Union Station
# Chinatown, Grange Park, Kensington Market

# %% [markdown]
# Let's check the size of the resulting dataframe

# %%
print(downtown_venues.shape)
downtown_venues.head()
# Out:
# (888, 7)
#                              Neighborhood  Neighborhood Latitude  \
# 0  First Canadian Place, Underground city              43.648429
# 1  First Canadian Place, Underground city              43.648429
# 2  First Canadian Place, Underground city              43.648429
# 3  First Canadian Place, Underground city              43.648429
# 4  First Canadian Place, Underground city              43.648429
#
#    Neighborhood Longitude                  Venue  Venue Latitude  \
# 0               -79.38228                  Canoe       43.647452
# 1               -79.38228     Equinox Bay Street       43.648100
# 2               -79.38228       Cactus Club Cafe       43.649552
# 3               -79.38228  Pilot Coffee Roasters       43.648835
# 4               -79.38228  Adelaide Club Toronto       43.649279
#
#    Venue Longitude        Venue Category
# 0       -79.381320            Restaurant
# 1       -79.379989                   Gym
# 2       -79.381671   American Restaurant
# 3       -79.380936           Coffee Shop
# 4       -79.381921  Gym / Fitness Center

# %% [markdown]
# Let's check how many venues were returned for each neighborhood

# %%
downtown_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Berczy Park                                                            59
# CN Tower, King and Spadina, Railway Lands, Sout...                     14
# Cabbagetown, St. James Town                                            42
# Chinatown, Grange Park, Kensington Market                              95
# Church and Wellesley                                                   88
# Commerce Court                                                        100
# Design Exchange, Toronto Dominion Centre                              100
# First Canadian Place, Underground city                                100
# Harbourfront                                                           50
# Rosedale                                                                4
# St. James Town                                                        100
# Toronto Islands, Union Station                                        100
# University of Toronto                                                  36
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Berczy Park                                                             59
# CN Tower, King and Spadina, Railway Lands, Sout...                      14
# Cabbagetown, St. James Town                                             42
# Chinatown, Grange Park, Kensington Market                               95
# Church and Wellesley                                                    88
# Commerce Court                                                         100
# Design Exchange, Toronto Dominion Centre                               100
# First Canadian Place, Underground city                                 100
# Harbourfront                                                            50
# Rosedale                                                                 4
# St. James Town                                                         100
# Toronto Islands, Union Station                                         100
# University of Toronto                                                   36
#
#                                                     Venue  Venue Latitude  \
# Neighborhood
# Berczy Park                                            59              59
# CN Tower, King and Spadina, Railway Lands, Sout...     14              14
# Cabbagetown, St. James Town                            42              42
# Chinatown, Grange Park, Kensington Market              95              95
# Church and Wellesley                                   88              88
# Commerce Court                                        100             100
# Design Exchange, Toronto Dominion Centre              100             100
# First Canadian Place, Underground city                100             100
# Harbourfront                                           50              50
# Rosedale                                                4               4
# St. James Town                                        100             100
# Toronto Islands, Union Station                        100             100
# University of Toronto                                  36              36
#
#                                                     Venue Longitude  \
# Neighborhood
# Berczy Park                                                      59
# CN Tower, King and Spadina, Railway Lands, Sout...               14
# Cabbagetown, St. James Town                                      42
# Chinatown, Grange Park, Kensington Market                        95
# Church and Wellesley                                             88
# Commerce Court                                                  100
# Design Exchange, Toronto Dominion Centre                        100
# First Canadian Place, Underground city                          100
# Harbourfront                                                     50
# Rosedale                                                          4
# St. James Town                                                  100
# Toronto Islands, Union Station                                  100
# University of Toronto                                            36
#
#                                                     Venue Category
# Neighborhood
# Berczy Park                                                     59
# CN Tower, King and Spadina, Railway Lands, Sout...              14
# Cabbagetown, St. James Town                                     42
# Chinatown, Grange Park, Kensington Market                       95
# Church and Wellesley                                            88
# Commerce Court                                                 100
# Design Exchange, Toronto Dominion Centre                       100
# First Canadian Place, Underground city                         100
# Harbourfront                                                    50
# Rosedale                                                         4
# St. James Town                                                 100
# Toronto Islands, Union Station                                 100
# University of Toronto                                           36

# %% [markdown]
# Number of uniques categories

# %%
print('There are {} uniques categories.'.format(len(downtown_venues['Venue Category'].unique())))
# Out:
# There are 187 uniques categories.

# %% [markdown]
# ### Analyze Each Neighborhood

# %%
# one hot encoding
downtown_onehot = pd.get_dummies(downtown_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
downtown_onehot['Neighborhood'] = downtown_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [downtown_onehot.columns[-1]] + list(downtown_onehot.columns[:-1])
downtown_onehot = downtown_onehot[fixed_columns]

downtown_grouped = downtown_onehot.groupby('Neighborhood').mean().reset_index()
downtown_grouped
# Out:
#                                          Neighborhood  Yoga Studio  \
# 0                                         Berczy Park     0.000000
# 1   CN Tower, King and Spadina, Railway Lands, Sou...     0.000000
# 2                         Cabbagetown, St. James Town     0.000000
# 3           Chinatown, Grange Park, Kensington Market     0.000000
# 4                                Church and Wellesley     0.011364
# 5                                      Commerce Court     0.000000
# 6            Design Exchange, Toronto Dominion Centre     0.000000
# 7              First Canadian Place, Underground city     0.000000
# 8                                        Harbourfront     0.020000
# 9                                            Rosedale     0.000000
# 10                                     St. James Town     0.000000
# 11                     Toronto Islands, Union Station     0.000000
# 12                              University of Toronto     0.000000
#
#     Afghan Restaurant   Airport  Airport Food Court  Airport Gate  \
# 0            0.000000  0.000000            0.000000      0.000000
# 1            0.000000  0.071429            0.071429      0.071429
# 2            0.000000  0.000000            0.000000      0.000000
# 3            0.000000  0.000000            0.000000      0.000000
# 4            0.011364  0.000000            0.000000      0.000000
# 5            0.000000  0.000000            0.000000      0.000000
# 6            0.000000  0.000000            0.000000      0.000000
# 7            0.000000  0.000000            0.000000      0.000000
# 8            0.000000  0.000000            0.000000      0.000000
# 9            0.000000  0.000000            0.000000      0.000000
# 10           0.000000  0.000000            0.000000      0.000000
# 11           0.000000  0.000000            0.000000      0.000000
# 12           0.000000  0.000000            0.000000      0.000000
#
#     Airport Lounge  Airport Service  Airport Terminal  American Restaurant  \
# 0         0.000000         0.000000          0.000000             0.000000
# 1         0.142857         0.142857          0.071429             0.000000
# 2         0.000000         0.000000          0.000000             0.000000
# 3         0.000000         0.000000          0.000000             0.000000
# 4         0.000000         0.000000          0.000000             0.011364
# 5         0.000000         0.000000          0.000000             0.030000
# 6         0.000000         0.000000          0.000000             0.030000
# 7         0.000000         0.000000          0.000000             0.030000
# 8         0.000000         0.000000          0.000000             0.000000
# 9         0.000000         0.000000          0.000000             0.000000
# 10        0.000000         0.000000          0.000000             0.020000
# 11        0.000000         0.000000          0.000000             0.000000
# 12        0.000000         0.000000          0.000000             0.000000
#
#     Antique Shop  Aquarium  Art Gallery  Arts & Crafts Store
0.03
#
#
# ----CN Tower, King and Spadina, Railway Lands, South Niagara----
#              venue  freq
# 0   Airport Lounge  0.14
# 1  Airport Service  0.14
# 2    Boat or Ferry  0.07
# 3            Plane  0.07
# 4              Bar  0.07
#
#
# ----Cabbagetown, St. James Town----
#                 venue  freq
# 0         Coffee Shop  0.07
# 1         Pizza Place  0.05
# 2  Italian Restaurant  0.05
# 3                 Pub  0.05
# 4                Café  0.05
#
#
# ----Chinatown, Grange Park, Kensington Market----
#                    venue  freq
# 0                   Café  0.08
# 1                    Bar  0.06
# 2  Vietnamese Restaurant  0.05
# 3            Coffee Shop  0.04
# 4     Chinese Restaurant  0.04
#
#
# ----Church and Wellesley----
#                  venue  freq
# 0          Coffee Shop  0.08
# 1  Japanese Restaurant  0.06
# 2     Sushi Restaurant  0.06
# 3              Gay Bar  0.03
# 4           Restaurant  0.03
#
#
# ----Commerce Court----
#          venue  freq
# 0  Coffee Shop  0.11
# 1         Café  0.07
# 2        Hotel  0.06
# 3   Restaurant  0.04
# 4   Steakhouse  0.03
#
#
# ----Design Exchange, Toronto Dominion Centre----
#          venue  freq
# 0  Coffee Shop  0.13
# 1         Café  0.08
# 2        Hotel  0.07
# 3          Bar  0.04
# 4   Restaurant  0.04
#
#
# ----First Canadian Place, Underground city----
#               venue  freq
# 0       Coffee Shop  0.11
# 1              Café  0.07
# 2             Hotel  0.04
# 3        Steakhouse  0.04
# 4  Asian Restaurant  0.03
#
#
# ----Harbourfront----
#          venue  freq
# 0  Coffee Shop  0.16
# 1       Bakery  0.06
# 2          Pub  0.06
# 3         Park  0.06
# 4      Theater  0.04
#
#
# ----Rosedale----
#          venue  freq
# 0         Park  0.50
# 1   Playground  0.25
# 2        Trail  0.25
# 3    Nightclub  0.00
# 4  Men's Store  0.00
#
#
# ----St. James Town----
#             venue  freq
# 0            Café  0.06
# 1     Coffee Shop  0.06
# 2           Hotel  0.05
# 3      Restaurant  0.05
# 4  Clothing Store  0.04
#
#
# ----Toronto Islands, Union Station----
#          venue  freq
# 0  Coffee Shop  0.13
# 1        Hotel  0.05
# 2     Aquarium  0.05
# 3         Café  0.04
# 4   Restaurant  0.03
#
#
# ----University of Toronto----
#                  venue  freq
# 0                 Café  0.17
# 1           Restaurant  0.06
# 2               Bakery  0.06
# 3   Italian Restaurant  0.06
# 4  Japanese Restaurant  0.06

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = downtown_grouped['Neighborhood']

for ind in np.arange(downtown_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(downtown_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                        Berczy Park           Coffee Shop
# 1  CN Tower, King and Spadina, Railway Lands, Sou...        Airport Lounge
# 2                        Cabbagetown, St. James Town           Coffee Shop
# 3          Chinatown, Grange Park, Kensington Market                  Café
# 4                               Church and Wellesley           Coffee Shop
#
#   2nd Most Common Venue  3rd Most Common Venue 4th Most Common Venue  \
# 0                Bakery                   Café        Farmers Market
# 1       Airport Service                    Bar      Sculpture Garden
# 2                Bakery                    Pub    Italian Restaurant
# 3                   Bar  Vietnamese Restaurant    Chinese Restaurant
# 4      Sushi Restaurant    Japanese Restaurant               Gay Bar
#
#   5th Most Common Venue     6th Most Common Venue  \
# 0              Beer Bar                Steakhouse
# 1         Boat or Ferry                   Airport
# 2                  Café               Pizza Place
# 3           Coffee Shop        Mexican Restaurant
# 4            Restaurant  Mediterranean Restaurant
#
#            7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0                    Cheese Shop          Cocktail Bar    Seafood Restaurant
# 1             Airport Food Court          Airport Gate      Airport Terminal
# 2                     Restaurant         Grocery Store  Gym / Fitness Center
# 3  Vegetarian / Vegan Restaurant                Bakery   Dumpling Restaurant
# 4                            Gym                 Hotel             Gastropub
#
#   10th Most Common Venue
# 0                 Lounge
# 1            Coffee Shop
# 2              Gift Shop
# 3                   Park
# 4                   Café

# %% [markdown]
# ### Cluster Neighborhoods
#
# Run k-means to cluster the neighborhood into 5 clusters.

# %%
# set number of clusters
kclusters = 5

downtown_grouped_clustering = downtown_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(downtown_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 

# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

downtown_merged = downtown_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
downtown_merged = downtown_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

downtown_merged.head() # check the last columns!
# Out:
#   PostalCode           Borough  \
# 0        M5X  Downtown Toronto
# 1        M4X  Downtown Toronto
# 2        M5K  Downtown Toronto
# 3        M5V  Downtown Toronto
# 4        M5L  Downtown Toronto
#
#                                         Neighborhood   Latitude  Longitude  \
# 0             First Canadian Place, Underground city  43.648429 -79.382280
# 1                        Cabbagetown, St. James Town  43.667967 -79.367675
# 2           Design Exchange, Toronto Dominion Centre  43.647177 -79.381576
# 3  CN Tower, King and Spadina, Railway Lands, Sou...  43.628947 -79.394420
# 4                                     Commerce Court  43.648198 -79.379817
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               4           Coffee Shop                  Café
# 1               0           Coffee Shop                Bakery
# 2               4           Coffee Shop                  Café
# 3               3        Airport Lounge       Airport Service
# 4               4           Coffee Shop                  Café
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0            Steakhouse                 Hotel   Japanese Restaurant
# 1                   Pub    Italian Restaurant                  Café
# 2                 Hotel            Restaurant                   Bar
# 3                   Bar      Sculpture Garden         Boat or Ferry
# 4                 Hotel            Restaurant            Steakhouse
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0      Asian Restaurant                   Bar    Seafood Restaurant
# 1           Pizza Place            Restaurant         Grocery Store
# 2            Steakhouse             Gastropub    Seafood Restaurant
# 3               Airport    Airport Food Court          Airport Gate
# 4             Gastropub    Seafood Restaurant         Deli / Bodega
#
#   9th Most Common Venue 10th Most Common Venue
# 0         Deli / Bodega    American Restaurant
# 1  Gym / Fitness Center              Gift Shop
# 2    Italian Restaurant    American Restaurant
# 3      Airport Terminal            Coffee Shop
# 4                Bakery                    Gym

# %% [markdown]
# Visualize the resulting clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(downtown_merged['Latitude'], downtown_merged['Longitude'], downtown_merged['Neighborhood'], downtown_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Examine Clusters

# %% [markdown]
# #### Cluster 1: CAFE & BAKERY

# %%
downtown_merged.loc[downtown_merged['Cluster Labels'] == 0, downtown_merged.columns[[1] + list(range(5, downtown_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 1   Downtown Toronto               0           Coffee Shop
# 8   Downtown Toronto               0           Coffee Shop
# 9   Downtown Toronto               0                  Café
# 12  Downtown Toronto               0                  Café
#
#    2nd Most Common Venue  3rd Most Common Venue 4th Most Common Venue  \
# 1                 Bakery                    Pub    Italian Restaurant
# 8                 Bakery                   Café        Farmers Market
# 9            Coffee Shop             Restaurant                 Hotel
# 12                   Bar  Vietnamese Restaurant    Chinese Restaurant
#
#    5th Most Common Venue 6th Most Common Venue          7th Most Common Venue  \
# 1                   Café           Pizza Place                     Restaurant
# 8               Beer Bar            Steakhouse                    Cheese Shop
# 9         Clothing Store                Bakery             Italian Restaurant
# 12           Coffee Shop    Mexican Restaurant  Vegetarian / Vegan Restaurant
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 1          Grocery Store  Gym / Fitness Center              Gift Shop
# 8           Cocktail Bar    Seafood Restaurant                 Lounge
# 9         Cosmetics Shop             Gastropub                  Diner
# 12                Bakery   Dumpling Restaurant                   Park

# %% [markdown]
# #### Cluster 2: ENTERTAINMENT

# %%
downtown_merged.loc[downtown_merged['Cluster Labels'] == 1, downtown_merged.columns[[1] + list(range(5, downtown_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 10  Downtown Toronto               1                  Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 10            Playground                 Trail           Wings Joint
#
#    5th Most Common Venue 6th Most Common Venue        7th Most Common Venue  \
# 10    Dim Sum Restaurant     Electronics Store  Eastern European Restaurant
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 10   Dumpling Restaurant            Donut Shop       Doner Restaurant

# %% [markdown]
# #### Cluster 3: BAR

# %%
downtown_merged.loc[downtown_merged['Cluster Labels'] == 2, downtown_merged.columns[[1] + list(range(5, downtown_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 5  Downtown Toronto               2                  Café
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 5   Japanese Restaurant    Italian Restaurant                   Bar
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 5                Bakery            Restaurant        Sandwich Place
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 5             Bookstore      Sushi Restaurant               Beer Bar

# %% [markdown]
# #### Cluster 4: AIRPORT

# %%
downtown_merged.loc[downtown_merged['Cluster Labels'] == 3, downtown_merged.columns[[1] + list(range(5, downtown_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 3  Downtown Toronto               3        Airport Lounge
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 3       Airport Service                   Bar      Sculpture Garden
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 3         Boat or Ferry               Airport    Airport Food Court
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 3          Airport Gate      Airport Terminal            Coffee Shop

# %% [markdown]
# #### Cluster 5: COFFEE SHOP

# %%
downtown_merged.loc[downtown_merged['Cluster Labels'] == 4, downtown_merged.columns[[1] + list(range(5, downtown_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 0   Downtown Toronto               4           Coffee Shop
# 2   Downtown Toronto               4           Coffee Shop
# 4   Downtown Toronto               4           Coffee Shop
# 6   Downtown Toronto               4           Coffee Shop
# 7   Downtown Toronto               4           Coffee Shop
# 11  Downtown Toronto               4           Coffee Shop
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                   Café            Steakhouse                 Hotel
# 2                   Café                 Hotel            Restaurant
# 4                   Café                 Hotel            Restaurant
# 6                   Park                Bakery                   Pub
# 7       Sushi Restaurant   Japanese Restaurant               Gay Bar
# 11              Aquarium                 Hotel                  Café
#
#    5th Most Common Venue     6th Most Common Venue 7th Most Common Venue  \
# 0    Japanese Restaurant          Asian Restaurant                   Bar
# 2                    Bar                Steakhouse             Gastropub
# 4             Steakhouse                 Gastropub    Seafood Restaurant
# 6                Theater        Mexican Restaurant                  Café
# 7             Restaurant  Mediterranean Restaurant                   Gym
# 11            Restaurant       Fried Chicken Joint    Italian Restaurant
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0     Seafood Restaurant         Deli / Bodega    American Restaurant
# 2     Seafood Restaurant    Italian Restaurant    American Restaurant
# 4          Deli / Bodega                Bakery                    Gym
# 6         Breakfast Spot            Restaurant         Farmers Market
# 7                  Hotel             Gastropub                   Café
# 11        Scenic Lookout               Brewery    Sporting Goods Shop
